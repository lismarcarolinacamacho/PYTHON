# %% [markdown]
# <a href="https://colab.research.google.com/github/lismarcarolinacamacho/PYTHON/blob/main/Graficos_con_Matplotlib%2C_Seaborn_y_Plotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # > Matplotlib

# %%
# 13.17

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from IPython.display import HTML
HTML('<iframe src=" https://matplotlib.org/stable/plot_types/index.html"  height="600" width="800"></iframe>')
# Out:
# <iframe src=" https://matplotlib.org/stable/plot_types/index.html"  height="600" width="800"></iframe>

# %%
# ?plt.plot # el simbolo ?  sirve de ayuda

# %%
plt.plot([0, 0.1,0.2,0.5],[1,-1,3,-1], color='g')

# %%
def f(x):
  return np.exp(-x ** 2)

# %%
x = np.linspace(-1, 5, num=30)

# %%
x
# Out:
# array([-1.        , -0.79310345, -0.5862069 , -0.37931034, -0.17241379,
#         0.03448276,  0.24137931,  0.44827586,  0.65517241,  0.86206897,
#         1.06896552,  1.27586207,  1.48275862,  1.68965517,  1.89655172,
#         2.10344828,  2.31034483,  2.51724138,  2.72413793,  2.93103448,
#         3.13793103,  3.34482759,  3.55172414,  3.75862069,  3.96551724,
#         4.17241379,  4.37931034,  4.5862069 ,  4.79310345,  5.        ])

# %%
plt.plot(x,f(x))

# %%
plt.plot(x,f(x))
plt.xlabel("Eje $x$")
plt.ylabel(" $f (x)$")
plt.title("Función $f(x)$")
# Out:
# Text(0.5, 1.0, 'Función $f(x)$')

# %%
plt.plot(x,f(x))
plt.xlabel("Eje $x$")
plt.ylabel("$f(x)$")
plt.legend("f(x)")
plt.title("Función $f(x)$")
# Out:
# Text(0.5, 1.0, 'Función $f(x)$')

# %%
plt.plot(x,f(x), 'ro')

# %%
plt.plot(x,1 - f(x), 'g') # inversa

# %%
plt.plot(x,1 - f(x), 'g--')

# %%
plt.plot(x,f(x), 'ro')
plt.plot(x,1 - f(x), 'g--') # inversa

# %%
plt.plot(x,f(x), 'ro')
plt.plot(x,1 - f(x), 'g--') # inversa
plt.grid("True")

# %%
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html

# %%
plt.plot(x,f(x), color="blue", linestyle='', marker='o')
plt.plot(x,1 - f(x), ls='--', c= 'y') # inversa
plt.grid("True")

# %%
print(plt.style.available) # todos estilos de los fondos de grafico que existen
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn')

# %%
plt.plot([1,2,3,4],[5,6,4,7])
plt.show()

# %%
plt.style.use('ggplot')
plt.plot([1,2,3,4],[5,6,4,7])
plt.show()

# %%
plt.style.use('dark_background')
plt.plot([1,2,3,4],[5,6,4,7])
plt.show()

# %% [markdown]
# # Scatterplots o dispersion de puntos

# %%
N= 100
x= np.random.rand(N)
y= np.random.rand(N)
x,y
# Out:
# (array([0.084199  , 0.09377205, 0.08853098, 0.43079361, 0.02960749,
#         0.75613654, 0.17645144, 0.60153777, 0.06148762, 0.76538182,
#         0.93705793, 0.4241779 , 0.63315729, 0.28770338, 0.66362141,
#         0.88283532, 0.40057291, 0.63305493, 0.63681059, 0.46188501,
#         0.53826969, 0.34854868, 0.9342404 , 0.93681076, 0.63027054,
#         0.89644231, 0.72472118, 0.35398683, 0.05092759, 0.62444224,
#         0.27478758, 0.11478887, 0.93091474, 0.34582798, 0.51348021,
#         0.88848761, 0.3342338 , 0.47867468, 0.46967494, 0.33455982,
#         0.42116248, 0.14985551, 0.02208737, 0.0239626 , 0.78205635,
#         0.60789172, 0.42485133, 0.99489863, 0.7892166 , 0.06981819,
#         0.6566699 , 0.84743698, 0.49457251, 0.63800144, 0.49371437,
#         0.33627763, 0.71250409, 0.13198843, 0.64573393, 0.3139216 ,
#         0.86478033, 0.85029333, 0.93624116, 0.69965132, 0.42530735,
#         0.61137862, 0.85763594, 0.26907558, 0.15437716, 0.79964407,
# ...

# %%
plt.style.use("ggplot")
plt.scatter(x,y)

# %%
s= 50*np.random.rand(N)
c= 50*np.random.rand(N)
s,c
# Out:
# (array([28.6166652 , 48.33462019,  6.55523098, 43.17388966, 28.33892276,
#         30.12038041, 10.1943715 , 15.66737512,  4.16228245, 26.46834381,
#         26.08408513, 27.63224914, 21.97457362,  3.402714  , 41.20579165,
#         26.86454059, 21.3539122 , 44.82732969,  2.44430019, 19.38096821,
#         42.64797066,  3.62089849, 46.04807063, 31.37078671, 21.36902949,
#         32.97860432, 34.8196059 , 35.24124623, 47.52361277, 26.13832099,
#          2.4482298 , 27.74378969, 44.21778538, 22.19163871, 20.09868919,
#         11.53447719,  2.80854644, 35.60578111, 13.63215881, 31.9897128 ,
#         32.24904406, 40.73193665, 12.92764553, 48.74891841, 12.81103538,
#          8.86301979, 39.61626322, 22.33893909, 19.02483688, 33.84944424,
#         22.13084304, 41.97294077, 40.00737383, 36.58913921, 37.09152531,
#         16.73566329, 15.1767443 , 49.63406625, 28.79912323,  3.12239987,
#         25.44320508, 16.27703091, 49.87354372, 27.99167653, 38.65221793,
# ...

# %%
plt.scatter(x,y,s,c,cmap=plt.cm.Oranges)

# %%
plt.scatter(x,y,s=s,c=c,cmap=plt.cm.Blues)
plt.colorbar()

# %% [markdown]
# # Box plot

# %%
np.random.seed(10)
data_1 = np.random.normal(100,10,200)
data_1
# Out:
# array([113.31586504, 107.15278974,  84.54599708,  99.9161615 ,
#        106.21335974,  92.79914439, 102.65511586, 101.08548526,
#        100.04291431,  98.25399789, 104.3302619 , 112.03037374,
#         90.34934329, 110.28274078, 102.2863013 , 104.45137613,
#         88.63397788, 101.35136878, 114.84537002,  89.20195114,
#         80.22271719,  82.56627704, 102.66070164, 123.84967331,
#         106.21335974,  92.79914439, 102.65511586, 101.08548526,
#         100.04291431,  98.25399789, 104.3302619 , 112.03037374,
#          90.34934329, 110.28274078, 102.2863013 , 104.45137613,
#          88.63397788, 101.35136878, 114.84537002,  89.20195114,
#          80.22271719,  82.56627704, 102.66070164, 123.84967331,
#         111.23691253, 116.72622213, 100.99149216, 113.97996377,
#          97.28752012, 106.13204185,  97.32682811,  94.50690986,
#         101.32708296,  95.23857985, 113.08473081, 101.95013279,
#         104.00209988,  96.62367663, 112.56472264,  92.68030498,
#         106.60231551,  96.49128109,  90.6056664 ,  95.10662783,
#          91.95408858,  97.87302361,  96.60859754, 103.12169936,
#         105.6515267 ,  98.52579742,  99.74094663, 102.89094204,
#          94.60120929, 107.0816002 , 108.42224738, 102.03580797,
#         123.94703665, 109.17458938,  98.87727529,  96.37819553,
# ...

# %%
np.shape(data_to_plot)
# Out:
# (3, 200)

# %%
np.size(data_to_plot)
# Out:
# 600

# %%
bp = plt.boxplot(data_to_plot)

# %%
# 26.01

# %%
#crear figuras , que un solo renglon me salgan dos graficas
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,9))

#primer grafico
bplot1= axes[0].boxplot(data_to_plot, vert=True, patch_artist=True)

#segundo garfico
bplot2= axes[1].boxplot(data_to_plot, notch= True, vert=True, patch_artist=True)

# colores de la paleta
colors=['pink','lightblue','lightgreen']

for bplot in (bplot1,bplot2):
  for patch, color in zip(bplot['boxes'],colors):
    patch.set_facecolor(color)

#nombres de las abcisas

plt.setp(axes, xticks=[y+1 for y in range(len(data_to_plot))],
xticklabels=['x1','x2','x3','x4'])
plt.show()

# %% [markdown]
# # Scatter Matrix

# %%
data= np.random.rand(1000,4)
data.shape
# Out:
# (1000, 4)

# %%
import pandas as pd


df = pd.DataFrame(np.random.rand(1000,4), columns =['a','b','c','d'])

# %%
df
# Out:
#             a         b         c         d
# 0    0.853161  0.520079  0.773754  0.560976
# 1    0.069615  0.965351  0.223291  0.723019
# 2    0.748780  0.005632  0.170543  0.363405
# 3    0.539697  0.864076  0.506914  0.879036
# 4    0.535803  0.552865  0.274310  0.089976
# ..        ...       ...       ...       ...
# 995  0.833484  0.659960  0.364886  0.547092
# 996  0.923265  0.354844  0.815810  0.015165
# 997  0.817403  0.838833  0.928698  0.820139
# 998  0.934258  0.796737  0.389408  0.460532
# 999  0.521538  0.735827  0.990523  0.543998
#
# [1000 rows x 4 columns]

# %%
spm=pd.plotting.scatter_matrix(df,alpha=0.2, figsize=(6,6), diagonal='hist')

#donde coincide a con a , (en la diagonal) hace un histograma

# %%
spm=pd.plotting.scatter_matrix(df,alpha=0.2, figsize=(6,6), diagonal='kde') #densidad de la estimacion

# %%
#32.10
